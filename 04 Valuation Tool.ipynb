# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np

# %%
# Get Raw Data
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2] 

# Create a pandas dataframe
df_data = pd.DataFrame(data, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO','B','LSTAT'])

# Add column with the price (target)
# df_data['target'] = (target)

df_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
features = df_data.drop(['INDUS', 'AGE'], axis=1)
log_prices = np.log(target)
target = pd.DataFrame(log_prices, columns=['PRICE'])
features
# Out:
#         CRIM    ZN  CHAS    NOX     RM     DIS  RAD    TAX  PTRATIO       B  \
# 0    0.00632  18.0   0.0  0.538  6.575  4.0900  1.0  296.0     15.3  396.90
# 1    0.02731   0.0   0.0  0.469  6.421  4.9671  2.0  242.0     17.8  396.90
# 2    0.02729   0.0   0.0  0.469  7.185  4.9671  2.0  242.0     17.8  392.83
# 3    0.03237   0.0   0.0  0.458  6.998  6.0622  3.0  222.0     18.7  394.63
# 4    0.06905   0.0   0.0  0.458  7.147  6.0622  3.0  222.0     18.7  396.90
# ..       ...   ...   ...    ...    ...     ...  ...    ...      ...     ...
# 501  0.06263   0.0   0.0  0.573  6.593  2.4786  1.0  273.0     21.0  391.99
# 502  0.04527   0.0   0.0  0.573  6.120  2.2875  1.0  273.0     21.0  396.90
# 503  0.06076   0.0   0.0  0.573  6.976  2.1675  1.0  273.0     21.0  396.90
# 504  0.10959   0.0   0.0  0.573  6.794  2.3889  1.0  273.0     21.0  393.45
# 505  0.04741   0.0   0.0  0.573  6.030  2.5050  1.0  273.0     21.0  396.90
#
#      LSTAT
# 0     4.98
# 1     9.14
# 2     4.03
# ...

# %%
CRIME_IDX = 0
ZN_IDX = 1
CHAS_IDX = 2
RM_IDX = 4
PTRATIO_IDX = 8

# property_stats = np.ndarray(shape=(1,11))
# property_stats[0][CRIME_IDX] = features['CRIM'].mean()
# property_stats[0][ZN_IDX] = features['ZN'].mean()
# property_stats[0][CHAS_IDX] = features['CHAS'].mean()

property_stats = features.mean().values.reshape(1,11)
property_stats
# Out:
# array([[3.61352356e+00, 1.13636364e+01, 6.91699605e-02, 5.54695059e-01,
#         6.28463439e+00, 3.79504269e+00, 9.54940711e+00, 4.08237154e+02,
#         1.84555336e+01, 3.56674032e+02, 1.26530632e+01]])

# %%
type(features.mean())
# Out:
# pandas.core.series.Series

# %%
type(features.mean().values)
# Out:
# numpy.ndarray

# %%
features.mean().values.reshape(1,11)
# Out:
# array([[3.61352356e+00, 1.13636364e+01, 6.91699605e-02, 5.54695059e-01,
#         6.28463439e+00, 3.79504269e+00, 9.54940711e+00, 4.08237154e+02,
#         1.84555336e+01, 3.56674032e+02, 1.26530632e+01]])

# %%
regr = LinearRegression().fit(features, target)
fitted_vals = regr.predict(features)

MSE = mean_squared_error(target, fitted_vals)
RMSE = np.sqrt(MSE)

# %%
def get_log_estimate(nr_rooms,students_per_classroom,next_to_river=False,high_confidence=True):
    # Configure property
    property_stats[0][RM_IDX] = nr_rooms
    property_stats[0][PTRATIO_IDX] = students_per_classroom
    
    if(next_to_river):
        property_stats[0][CHAS_IDX] = 1
    else:
        property_stats[0][CHAS_IDX] = 0
    
    # Make prediction
    log_estimate = regr.predict(property_stats)[0][0]
    
    # Calc Range
    if high_confidence:
        upper_bound = log_estimate + 2*RMSE
        lower_bound = log_estimate - 2*RMSE
        interval = 95
    else:
        upper_bound = log_estimate + RMSE
        lower_bound = log_estimate - RMSE   
        interval = 68
        
    return log_estimate, upper_bound, lower_bound, interval

# %%
get_log_estimate(3,20, next_to_river=True, high_confidence=False)
# Out:
# /home/somsakra/notebook/notebook_env/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# (2.7767581914804005, 2.9642703266775308, 2.58924605628327, 68)

# %%
raw_target = raw_df.values[1::2, 2]
np.median(raw_target)
# Out:
# 21.2

# %%
ZILLOW_MEDIAN_PRICE = 583.3
SCAL_FACTOR = ZILLOW_MEDIAN_PRICE / np.median(raw_target)
SCAL_FACTOR

log_est, upper, lower, conf = get_log_estimate(9, students_per_classroom=15, next_to_river=False, high_confidence=False)

# Convert to today's dollars

dollar_est = np.e**log_est * 1000 * SCAL_FACTOR 
dollar_high = np.e**upper * 1000 * SCAL_FACTOR 
dollar_low = np.e**lower * 1000 * SCAL_FACTOR 


# Round the dollar values to nearest thousand
rounded_est = np.around(dollar_est, -3)
rounded_hi = np.around(dollar_high, -3)
rounded_low = np.around(dollar_low, -3)

print(f'The estimated property value is {rounded_est}.')
print(f'At {conf}% confidence the valuation range is')
print(f'USD {rounded_low} at the lower end to USD {rounded_hi} at the high end.')
# Out:
# The estimated property value is 827000.0.
# At 68% confidence the valuation range is
# USD 685000.0 at the lower end to USD 997000.0 at the high end.
# /home/somsakra/notebook/notebook_env/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
def get_dollar_estimate(rm, ptratio, chas=False, large_range=True):
    """Estimate the price of a properties in Boston.
    
    Keyword arguments:
    rm -- number of room in the property
    ptratio -- number of students per teacher in the classroom fo the school in the area
    chas -- True if the property is next to the river, False otherwise.
    large_range -- True for a 95% prediction interval, False for a 68% interval.
    
    """
    
    if rm < 1 or ptratio < 1:
        print('That is unrealistic. Try again.')
        return
    
    log_est, upper, lower, conf = get_log_estimate(rm, ptratio, 
                                                   next_to_river=chas, high_confidence=large_range)

    # Convert to today's dollars

    dollar_est = np.e**log_est * 1000 * SCAL_FACTOR 
    dollar_high = np.e**upper * 1000 * SCAL_FACTOR 
    dollar_low = np.e**lower * 1000 * SCAL_FACTOR 


    # Round the dollar values to nearest thousand
    rounded_est = np.around(dollar_est, -3)
    rounded_hi = np.around(dollar_high, -3)
    rounded_low = np.around(dollar_low, -3)

    print(f'The estimated property value is {rounded_est}.')
    print(f'At {conf}% confidence the valuation range is')
    print(f'USD {rounded_low} at the lower end to USD {rounded_hi} at the high end.')

# %%
get_dollar_estimate(rm=6, ptratio=-6, chas=True)
# Out:
# That is unrealistic. Try again.

# %%
import boston_valuation as val

val.get_dollar_estimate(6,12,True)
# Out:
# The estimated property value is 783000.0.
# At 95% confidence the valuation range is
# USD 538000.0 at the lower end to USD 1139000.0 at the high end.
# /home/somsakra/notebook/notebook_env/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
